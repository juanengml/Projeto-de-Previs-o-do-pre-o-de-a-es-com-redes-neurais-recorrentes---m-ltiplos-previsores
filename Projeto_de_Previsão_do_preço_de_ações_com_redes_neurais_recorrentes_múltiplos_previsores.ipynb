# %% [markdown]
# # Projeto 21: Previsão do preço de ações com redes neurais recorrentes - múltiplos previsores

# %% [markdown]
# ## Etapa 1: Importação das bibliotecas

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import torch
from torch import nn, optim
from sklearn.metrics import mean_absolute_error
torch.__version__
# Out:
# '1.6.0+cu101'

# %%
torch.manual_seed(123)

# %% [markdown]
# ## Etapa 2: Base de dados

# %%
base = pd.read_csv('petr4_treinamento.csv')
base = base.dropna()
base_treinamento = base.iloc[:, 1:7].values

# %%
base_treinamento
# Out:
# array([[1.9990000e+01, 2.0209999e+01, 1.9690001e+01, 1.9690001e+01,
#         1.8086271e+01, 3.0182600e+07],
#        [1.9809999e+01, 2.0400000e+01, 1.9700001e+01, 2.0400000e+01,
#         1.8738441e+01, 3.0552600e+07],
#        [2.0330000e+01, 2.0620001e+01, 2.0170000e+01, 2.0430000e+01,
#         1.8766001e+01, 3.6141000e+07],
#        ...,
#        [1.5990000e+01, 1.6139999e+01, 1.5980000e+01, 1.6049999e+01,
#         1.6017963e+01, 2.3552200e+07],
#        [1.6100000e+01, 1.6129999e+01, 1.6000000e+01, 1.6100000e+01,
#         1.6067865e+01, 1.9011500e+07],
#        [1.6100000e+01, 1.6100000e+01, 1.6100000e+01, 1.6100000e+01,
#         1.6067865e+01, 0.0000000e+00]])

# %%
base.head()
# Out:
#          Date       Open       High  ...      Close  Adj Close      Volume
# 0  2013-01-02  19.990000  20.209999  ...  19.690001  18.086271  30182600.0
# 1  2013-01-03  19.809999  20.400000  ...  20.400000  18.738441  30552600.0
# 2  2013-01-04  20.330000  20.620001  ...  20.430000  18.766001  36141000.0
# 3  2013-01-07  20.480000  20.670000  ...  20.080000  18.444506  28069600.0
# 4  2013-01-08  20.110001  20.230000  ...  19.500000  17.911745  29091300.0
#
# [5 rows x 7 columns]

# %%
normalizador = MinMaxScaler(feature_range = (0, 1))
base_treinamento_normalizada = normalizador.fit_transform(base_treinamento)

# %%
base_treinamento_normalizada
# Out:
# array([[0.76501938, 0.77266112, 0.79682707, 0.76080559, 0.6838135 ,
#         0.04318274],
#        [0.7562984 , 0.78187106, 0.79733884, 0.79567784, 0.71590949,
#         0.0437121 ],
#        [0.78149225, 0.79253519, 0.82139202, 0.79715132, 0.71726583,
#         0.05170752],
#        ...,
#        [0.57122093, 0.57537562, 0.60696008, 0.58202356, 0.58202349,
#         0.03369652],
#        [0.57655039, 0.57489089, 0.60798362, 0.5844794 , 0.58447937,
#         0.02720006],
#        [0.57655039, 0.57343674, 0.61310133, 0.5844794 , 0.58447937,
#         0.        ]])

# %%
X = []
y = []
for i in range(90, 1242):
    X.append(base_treinamento_normalizada[i-90:i, 0:6])
    y.append(base_treinamento_normalizada[i, 0])
X, y = np.array(X), np.array(y)

# %%
X[0]
# Out:
# array([[0.76501938, 0.77266112, 0.79682707, 0.76080559, 0.6838135 ,
#         0.04318274],
#        [0.7562984 , 0.78187106, 0.79733884, 0.79567784, 0.71590949,
#         0.0437121 ],
#        [0.64341085, 0.6776539 , 0.68372569, 0.68516703, 0.61419665,
#         0.04400526],
#        [0.67877902, 0.69704314, 0.71903787, 0.69842833, 0.6264022 ,
#         0.04546845],
#        [0.69137592, 0.69122642, 0.7036848 , 0.67730848, 0.60696374,
#         0.03177292],
#        [0.66569772, 0.66941348, 0.6862846 , 0.67583495, 0.6056075 ,
#         0.03919891],
#        [0.65406982, 0.6572952 , 0.665302  , 0.63998039, 0.57260735,
#         0.05120333],
#        [0.64292631, 0.65341735, 0.68116684, 0.66306491, 0.59385423,
#         0.03397579],
#        [0.64147292, 0.64614639, 0.65813715, 0.63703343, 0.56989516,
#         0.05635362],
#        [0.63565891, 0.66262729, 0.665302  , 0.66895878, 0.5992789 ,
#         0.04077971],
#        [0.67587209, 0.68880271, 0.70777897, 0.6969548 , 0.625046  ,
#         0.0548714 ],
#        [0.68653106, 0.70382942, 0.71903787, 0.71660126, 0.64312846,
#         0.03461346],
#        [0.70300383, 0.73921474, 0.74411464, 0.73280952, 0.6580463 ,
#         0.04969664],
#        [0.71996119, 0.74600097, 0.76202661, 0.74852661, 0.67251211,
#         0.04766145],
#        [0.73982553, 0.74745521, 0.76867958, 0.73526526, 0.66030651,
#         0.05031056],
#        [0.76550388, 0.79059622, 0.80962134, 0.79666016, 0.71681365,
#         0.10120858],
#        [0.74854651, 0.76732913, 0.7840328 , 0.7804519 , 0.71911682,
#         0.06567045],
#        [0.75823643, 0.79301983, 0.80501535, 0.78831045, 0.72648688,
#         0.04828195],
#        [0.78924419, 0.79447407, 0.80706238, 0.77455795, 0.71358928,
#         0.06152981],
#        [0.76598837, 0.78041692, 0.80348004, 0.79223972, 0.73017189,
#         0.04455508],
#        [0.78488372, 0.79835191, 0.82702155, 0.80648339, 0.74353023,
#         0.03775975],
#        [0.80184109, 0.80222976, 0.82395082, 0.79027514, 0.72832946,
#         0.03492235],
#        [0.77761628, 0.78768783, 0.81729785, 0.7907662 , 0.72879006,
#         0.03271233],
#        [0.77325581, 0.78138628, 0.79785051, 0.77406679, 0.71312854,
#         0.0315204 ],
#        [0.7562984 , 0.75521086, 0.78096208, 0.75098236, 0.69147899,
#         0.03087142],
#        [0.74273261, 0.74697043, 0.77430911, 0.75392926, 0.69424286,
#         0.04384244],
#        [0.74127907, 0.74503146, 0.77840328, 0.75491163, 0.6951641 ,
#         0.03128876],
#        [0.74224806, 0.76635967, 0.78505624, 0.76375249, 0.7034554 ,
#         0.03586405]])

# %%
y[0]
# Out:
# 0.7611434108527131

# %%
X[1]
# Out:
# array([[0.7562984 , 0.78187106, 0.79733884, 0.79567784, 0.71590949,
#         0.0437121 ],
#        [0.78149225, 0.79253519, 0.82139202, 0.79715132, 0.71726583,
#         0.05170752],
#        [0.78875969, 0.7949588 , 0.81013311, 0.77996075, 0.70144373,
#         0.04015963],
#        [0.77083338, 0.77363063, 0.78505624, 0.75147351, 0.67522435,
#         0.0416214 ],
#        [0.66569772, 0.66941348, 0.6862846 , 0.67583495, 0.6056075 ,
#         0.03919891],
#        [0.65406982, 0.6572952 , 0.665302  , 0.63998039, 0.57260735,
#         0.05120333],
#        [0.64292631, 0.65341735, 0.68116684, 0.66306491, 0.59385423,
#         0.03397579],
#        [0.64147292, 0.64614639, 0.65813715, 0.63703343, 0.56989516,
#         0.05635362],
#        [0.63565891, 0.66262729, 0.665302  , 0.66895878, 0.5992789 ,
#         0.04077971],
#        [0.67587209, 0.68880271, 0.70777897, 0.6969548 , 0.625046  ,
#         0.0548714 ],
#        [0.68653106, 0.70382942, 0.71903787, 0.71660126, 0.64312846,
#         0.03461346],
#        [0.70300383, 0.73921474, 0.74411464, 0.73280952, 0.6580463 ,
#         0.04969664],
#        [0.71996119, 0.74600097, 0.76202661, 0.74852661, 0.67251211,
#         0.04766145],
#        [0.73982553, 0.74745521, 0.76867958, 0.73526526, 0.66030651,
#         0.05031056],
#        [0.76550388, 0.79059622, 0.80962134, 0.79666016, 0.71681365,
#         0.10120858],
#        [0.74854651, 0.76732913, 0.7840328 , 0.7804519 , 0.71911682,
#         0.06567045],
#        [0.75823643, 0.79301983, 0.80501535, 0.78831045, 0.72648688,
#         0.04828195],
#        [0.78924419, 0.79447407, 0.80706238, 0.77455795, 0.71358928,
#         0.06152981],
#        [0.76598837, 0.78041692, 0.80348004, 0.79223972, 0.73017189,
#         0.04455508],
#        [0.78488372, 0.79835191, 0.82702155, 0.80648339, 0.74353023,
#         0.03775975],
#        [0.80184109, 0.80222976, 0.82395082, 0.79027514, 0.72832946,
#         0.03492235],
#        [0.77761628, 0.78768783, 0.81729785, 0.7907662 , 0.72879006,
#         0.03271233],
#        [0.77325581, 0.78138628, 0.79785051, 0.77406679, 0.71312854,
#         0.0315204 ],
#        [0.7562984 , 0.75521086, 0.78096208, 0.75098236, 0.69147899,
#         0.03087142],
#        [0.74273261, 0.74697043, 0.77430911, 0.75392926, 0.69424286,
#         0.04384244],
#        [0.74127907, 0.74503146, 0.77840328, 0.75491163, 0.6951641 ,
#         0.03128876],
#        [0.74224806, 0.76635967, 0.78505624, 0.76375249, 0.7034554 ,
#         0.03586405],
#        [0.76114341, 0.76490543, 0.80194478, 0.77062867, 0.70990428,
#         0.02724098]])

# %%
y[1]
# Out:
# 0.7611434108527131

# %%
X = torch.tensor(X, dtype = torch.float32)
y = torch.tensor(y, dtype = torch.float32)

# %%
dataset = torch.utils.data.TensorDataset(X, y)
loader = torch.utils.data.DataLoader(dataset, batch_size = 32, shuffle = True)

# %% [markdown]
# ## Etapa 3: Construção da rede neural recorrente

# %%
class regressor_LSTM(nn.Module):
    def __init__(self):
        super().__init__()
        
        # O primeiro input_size é o número de dimensões que cada dado tem em 
        # cada timestep. Nesse caso, são 6 dimensões, uma para cada variável.
        self.lstm1 = nn.LSTM(input_size = 6, hidden_size = 100)
        self.lstm2 = nn.LSTM(100, 50)
        self.lstm3 = nn.LSTM(50, 50, dropout = 0.3, num_layers = 2)
        self.dropout = nn.Dropout(p = 0.3)
        self.linear = nn.Linear(in_features = 50, out_features = 1)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, X):
        
        X = X.permute(1, 0, 2)
        X, _ = self.lstm1(X)
        X = self.dropout(X)
        X, _ = self.lstm2(X)
        X = self.dropout(X)
        X, _ = self.lstm3(X)
        
        X = X[-1]
        X = self.dropout(X)
        X = self.linear(X)
        X = self.sigmoid(X)
       
        return X

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
regressor = regressor_LSTM()
criterion = nn.MSELoss()
optimizer = optim.Adam(regressor.parameters())

# %%
regressor.to(device)
# Out:
# regressor_LSTM(
#   (lstm1): LSTM(6, 100)
#   (lstm2): LSTM(100, 50)
#   (lstm3): LSTM(50, 50, num_layers=2, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (linear): Linear(in_features=50, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# ## Etapa 4: Treinamento do modelo

# %%
# Variáveis para o callback
ES_MIN_DELTA = 1e-10
ES_PATIENCE = 10
RLR_FACTOR = 0.2
RLR_PATIENCE = 5

# Inicializando o custo inicial para usar nos callbacks
min_loss = np.inf

# %%
for epoch in range(200):
    running_loss = 0.
    running_mae = 0.
          
    for i, data in enumerate(loader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        outputs = regressor(inputs)
        outputs = outputs.flatten()
        
        loss = criterion(outputs, labels)
        loss.backward()
        
        optimizer.step()
    
        running_loss += loss.item()
        mae = mean_absolute_error(labels.detach().cpu().numpy().flatten(), 
                                  outputs.detach().cpu().numpy().flatten())
        running_mae += mae
        
        # Imprimindo os dados referentes a esse loop 
        print('\rÉpoca {:3d} - Loop {:3d} de {:3d}: custo {:03.5f} - MAE {:03.5f}'.format(epoch+1, i+1, len(loader), loss, mae), end = '\r')
    
    # Imprimindo os dados referentes a essa época
    running_loss /= len(loader)
    running_mae /= len(loader)
    print('ÉPOCA {:3d} finalizada: custo {:03.6f} - MAE {:03.6f}     '.format(epoch+1, running_loss, running_mae))
    
    # CALLBACKS
    
    # Salvar o modelo
    
    if running_loss < min_loss:
        print('**Custo reduzido de {:03.6f} para {:03.6f} ... salvando checkpoint'.format(min_loss, running_loss))
        torch.save(regressor.state_dict(), 'checkpoint.pth')
        min_loss = running_loss
        es_patience = 0
        rlr_patience = 0
    else:
        print('**Custo não reduziu, não salvando checkpoint')
        
        # Os demais parâmetros só serão considerados se o custo não tiver 
               
        # Parada antecipada
        if running_loss - min_loss >= ES_MIN_DELTA:
            es_patience += 1
            if es_patience == ES_PATIENCE:
                print('--Critério de parada antecipada alcançado, parando o treinamento.')
                break
            
        # Reduzir a taxa de aprendizagem
        rlr_patience += 1
        if rlr_patience == RLR_PATIENCE:
            print('--Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.')
            for param_group in optimizer.param_groups:
                param_group['lr'] *= RLR_FACTOR
            rlr_patience = 0
# Out:
# ÉPOCA   1 finalizada: custo 0.024246 - MAE 0.119286
# **Custo reduzido de inf para 0.024246 ... salvando checkpoint
# ÉPOCA   2 finalizada: custo 0.004805 - MAE 0.053791
# **Custo reduzido de 0.024246 para 0.004805 ... salvando checkpoint
# ÉPOCA   3 finalizada: custo 0.003434 - MAE 0.044777
# **Custo reduzido de 0.004805 para 0.003434 ... salvando checkpoint
# ÉPOCA   4 finalizada: custo 0.002927 - MAE 0.041494
# **Custo reduzido de 0.003434 para 0.002927 ... salvando checkpoint
# ÉPOCA   5 finalizada: custo 0.002410 - MAE 0.037681
# **Custo reduzido de 0.002927 para 0.002410 ... salvando checkpoint
# ÉPOCA   6 finalizada: custo 0.002470 - MAE 0.038013
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA   7 finalizada: custo 0.002342 - MAE 0.036743
# **Custo reduzido de 0.002410 para 0.002342 ... salvando checkpoint
# ÉPOCA   8 finalizada: custo 0.002110 - MAE 0.035269
# **Custo reduzido de 0.002342 para 0.002110 ... salvando checkpoint
# ÉPOCA   9 finalizada: custo 0.002091 - MAE 0.034767
# **Custo reduzido de 0.002110 para 0.002091 ... salvando checkpoint
# ÉPOCA  10 finalizada: custo 0.002190 - MAE 0.035259
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  11 finalizada: custo 0.002296 - MAE 0.036330
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  12 finalizada: custo 0.001803 - MAE 0.031698
# **Custo reduzido de 0.002091 para 0.001803 ... salvando checkpoint
# ÉPOCA  13 finalizada: custo 0.001803 - MAE 0.032537
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  14 finalizada: custo 0.001597 - MAE 0.030298
# **Custo reduzido de 0.001803 para 0.001597 ... salvando checkpoint
# ÉPOCA  15 finalizada: custo 0.001735 - MAE 0.031697
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  16 finalizada: custo 0.001724 - MAE 0.031348
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  17 finalizada: custo 0.001583 - MAE 0.029851
# **Custo reduzido de 0.001597 para 0.001583 ... salvando checkpoint
# ÉPOCA  18 finalizada: custo 0.001581 - MAE 0.030128
# **Custo reduzido de 0.001583 para 0.001581 ... salvando checkpoint
# ÉPOCA  19 finalizada: custo 0.001499 - MAE 0.029288
# **Custo reduzido de 0.001581 para 0.001499 ... salvando checkpoint
# ÉPOCA  20 finalizada: custo 0.001625 - MAE 0.030620
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  21 finalizada: custo 0.001603 - MAE 0.030179
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  22 finalizada: custo 0.001506 - MAE 0.028727
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  23 finalizada: custo 0.001503 - MAE 0.029089
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  24 finalizada: custo 0.001470 - MAE 0.029272
# **Custo reduzido de 0.001499 para 0.001470 ... salvando checkpoint
# ÉPOCA  25 finalizada: custo 0.001410 - MAE 0.028334
# **Custo reduzido de 0.001470 para 0.001410 ... salvando checkpoint
# ÉPOCA  26 finalizada: custo 0.001361 - MAE 0.027748
# **Custo reduzido de 0.001410 para 0.001361 ... salvando checkpoint
# ÉPOCA  27 finalizada: custo 0.001318 - MAE 0.027704
# **Custo reduzido de 0.001361 para 0.001318 ... salvando checkpoint
# ÉPOCA  28 finalizada: custo 0.001314 - MAE 0.026807
# **Custo reduzido de 0.001318 para 0.001314 ... salvando checkpoint
# ÉPOCA  29 finalizada: custo 0.001208 - MAE 0.026459
# **Custo reduzido de 0.001314 para 0.001208 ... salvando checkpoint
# ÉPOCA  30 finalizada: custo 0.001135 - MAE 0.025271
# **Custo reduzido de 0.001208 para 0.001135 ... salvando checkpoint
# ÉPOCA  31 finalizada: custo 0.001109 - MAE 0.024964
# **Custo reduzido de 0.001135 para 0.001109 ... salvando checkpoint
# ÉPOCA  32 finalizada: custo 0.001115 - MAE 0.024233
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  33 finalizada: custo 0.001134 - MAE 0.024784
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  34 finalizada: custo 0.001032 - MAE 0.023608
# **Custo reduzido de 0.001109 para 0.001032 ... salvando checkpoint
# ÉPOCA  35 finalizada: custo 0.001204 - MAE 0.025902
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  36 finalizada: custo 0.001115 - MAE 0.024969
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  37 finalizada: custo 0.001050 - MAE 0.024571
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  38 finalizada: custo 0.001046 - MAE 0.024072
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  39 finalizada: custo 0.001096 - MAE 0.024991
# **Custo não reduziu, não salvando checkpoint
# --Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.
# ÉPOCA  40 finalizada: custo 0.000894 - MAE 0.022467
# **Custo reduzido de 0.001032 para 0.000894 ... salvando checkpoint
# ÉPOCA  41 finalizada: custo 0.000965 - MAE 0.022901
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  42 finalizada: custo 0.000891 - MAE 0.021908
# **Custo reduzido de 0.000894 para 0.000891 ... salvando checkpoint
# ÉPOCA  43 finalizada: custo 0.000909 - MAE 0.022263
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  44 finalizada: custo 0.000873 - MAE 0.021802
# **Custo reduzido de 0.000891 para 0.000873 ... salvando checkpoint
# ÉPOCA  45 finalizada: custo 0.000877 - MAE 0.021731
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  46 finalizada: custo 0.000913 - MAE 0.021988
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  47 finalizada: custo 0.000878 - MAE 0.021794
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  48 finalizada: custo 0.000951 - MAE 0.022450
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  49 finalizada: custo 0.000897 - MAE 0.021860
# **Custo não reduziu, não salvando checkpoint
# --Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.
# ÉPOCA  50 finalizada: custo 0.000896 - MAE 0.021583
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  51 finalizada: custo 0.000838 - MAE 0.021142
# **Custo reduzido de 0.000873 para 0.000838 ... salvando checkpoint
# ÉPOCA  52 finalizada: custo 0.000876 - MAE 0.021860
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  53 finalizada: custo 0.000875 - MAE 0.021697
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  54 finalizada: custo 0.000867 - MAE 0.021947
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  55 finalizada: custo 0.000830 - MAE 0.021324
# **Custo reduzido de 0.000838 para 0.000830 ... salvando checkpoint
# ÉPOCA  56 finalizada: custo 0.000893 - MAE 0.021793
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  57 finalizada: custo 0.000805 - MAE 0.021172
# **Custo reduzido de 0.000830 para 0.000805 ... salvando checkpoint
# ÉPOCA  58 finalizada: custo 0.000849 - MAE 0.021494
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  59 finalizada: custo 0.000794 - MAE 0.020468
# **Custo reduzido de 0.000805 para 0.000794 ... salvando checkpoint
# ÉPOCA  60 finalizada: custo 0.000883 - MAE 0.021856
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  61 finalizada: custo 0.000899 - MAE 0.021891
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  62 finalizada: custo 0.000820 - MAE 0.021008
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  63 finalizada: custo 0.000855 - MAE 0.021624
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  64 finalizada: custo 0.000834 - MAE 0.021188
# **Custo não reduziu, não salvando checkpoint
# --Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.
# ÉPOCA  65 finalizada: custo 0.000804 - MAE 0.021069
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  66 finalizada: custo 0.000832 - MAE 0.021284
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  67 finalizada: custo 0.000838 - MAE 0.021501
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  68 finalizada: custo 0.000849 - MAE 0.021442
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  69 finalizada: custo 0.000860 - MAE 0.021489
# **Custo não reduziu, não salvando checkpoint
# --Critério de parada antecipada alcançado, parando o treinamento.

# %% [markdown]
# ## Etapa 5: Processamento da base de teste

# %%
base_teste = pd.read_csv('petr4_teste.csv')
preco_real_teste = base_teste.iloc[:, 1:2].values
base_completa = pd.concat([base, base_teste])

# %%
base_completa.head()
# Out:
#          Date       Open       High  ...      Close  Adj Close      Volume
# 0  2013-01-02  19.990000  20.209999  ...  19.690001  18.086271  30182600.0
# 1  2013-01-03  19.809999  20.400000  ...  20.400000  18.738441  30552600.0
# 2  2013-01-04  20.330000  20.620001  ...  20.430000  18.766001  36141000.0
# 3  2013-01-07  20.480000  20.670000  ...  20.080000  18.444506  28069600.0
# 4  2013-01-08  20.110001  20.230000  ...  19.500000  17.911745  29091300.0
#
# [5 rows x 7 columns]

# %%
base_completa = base_completa.drop('Date', axis = 1)

# %%
entradas = base_completa[len(base_completa) - len(base_teste) - 90:].values
entradas = normalizador.transform(entradas)

# %%
X_teste = []
for i in range(90, 112):
    X_teste.append(entradas[i-90:i, 0:6])
X_teste = np.array(X_teste)

# %%
X_teste = torch.tensor(X_teste, device = device, dtype = torch.float32)

# %% [markdown]
# ## Etapa 6: Previsões

# %%
regressor.eval()
previsoes = regressor(X_teste)
previsoes = previsoes.detach().cpu().numpy().reshape(-1, 1)

# %%
previsoes
# Out:
# array([[0.5781712 ],
#        [0.5862836 ],
#        [0.59898424],
#        [0.610638  ],
#        [0.6149947 ],
#        [0.6174533 ],
#        [0.6215233 ],
#        [0.61978585],
#        [0.62262636],
#        [0.63000804],
#        [0.6372698 ],
#        [0.6466609 ],
#        [0.66848385],
#        [0.6850208 ],
#        [0.6887645 ],
#        [0.68815863],
#        [0.68425447],
#        [0.7030623 ],
#        [0.72896826],
#        [0.74983597],
#        [0.7605853 ],
#        [0.75559324]], dtype=float32)

# %%
normalizador_previsao = MinMaxScaler(feature_range = (0, 1))
normalizador_previsao.fit(base_treinamento[:, 0:1])
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
previsoes = normalizador_previsao.inverse_transform(previsoes)

# %%
previsoes
# Out:
# array([[16.133453],
#        [16.300894],
#        [16.563034],
#        [16.803568],
#        [16.89349 ],
#        [16.944235],
#        [17.02824 ],
#        [16.99238 ],
#        [17.051008],
#        [17.203365],
#        [17.353249],
#        [17.547081],
#        [17.997507],
#        [18.338829],
#        [18.4161  ],
#        [18.403593],
#        [18.323011],
#        [18.711205],
#        [19.245905],
#        [19.676615],
#        [19.89848 ],
#        [19.795444]], dtype=float32)

# %%
previsoes.mean()
# Out:
# 17.80094

# %%
preco_real_teste.mean()
# Out:
# 17.87454563636364

# %%
plt.plot(preco_real_teste, color = 'red', label = 'Preço real')
plt.plot(previsoes, color = 'blue', label = 'Previsões')
plt.title('Previsão preço das ações')
plt.xlabel('Tempo')
plt.ylabel('Valor Yahoo')
plt.legend()
